# %% [markdown]
# # Machine Learning Essay Questions
#
# Answer the questions below in your own words.

# %% [markdown]
# ### BEGIN QUESTION_LLM
# What is the difference between supervised and unsupervised learning?
# Give at least one concrete example of each.
# ### END QUESTION_LLM
#
# ### BEGIN CRITERIA_LLM
# Give 5 points if the student correctly distinguishes supervised (labeled data) from unsupervised (unlabeled data) learning.
# Give 3 points for providing a concrete example of supervised learning (e.g. classification, regression).
# Give 2 points for providing a concrete example of unsupervised learning (e.g. clustering, dimensionality reduction).
# ### END CRITERIA_LLM

# %% [markdown]
# ### BEGIN QUESTION_LLM
# Explain what overfitting is and how to prevent it.
# ### END QUESTION_LLM
#
# ### BEGIN CRITERIA_LLM
# Give 3 points for a correct explanation of overfitting (model memorises training data, poor generalisation).
# Give 2 points for mentioning at least one prevention technique (regularisation, cross-validation, more data, dropout, etc.).
# ### END CRITERIA_LLM
